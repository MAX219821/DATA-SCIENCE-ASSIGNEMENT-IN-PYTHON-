# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('EastWestAirlines.xlsx',sheet_name="data" )

# %%
df.shape
# Out:
# (3999, 12)

# %%
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df.tail()
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 3994       1
# 3995       1
# 3996       1
# 3997       0
# 3998       0

# %%
df.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# min       1.000000       0.000000      0.00000           0.000000
# 25%       1.000000    1250.000000      3.00000           0.000000
# 50%       1.000000    7171.000000     12.00000           0.000000
# 75%       1.000000   23800.500000     17.00000         311.000000
# max       5.000000  263685.000000     86.00000       30817.000000
#
#        Flight_trans_12  Days_since_enroll       Award?
# count      3999.000000         3999.00000  3999.000000
# mean          1.373593         4118.55939     0.370343
# std           3.793172         2065.13454     0.482957
# min           0.000000            2.00000     0.000000
# 25%           0.000000         2330.00000     0.000000
# 50%           0.000000         4096.00000     0.000000
# 75%           1.000000         5790.50000     1.000000
# max          53.000000         8296.00000     1.000000

# %%
#standardize the data to normal distribution
from sklearn import preprocessing
df_standardized = preprocessing.scale(df)
print(df_standardized)
df_standardized = pd.DataFrame(df_standardized)
# Out:
# [[-1.73512503e+00 -4.51140783e-01 -1.86298687e-01 ... -3.62167870e-01
#    1.39545434e+00 -7.66919299e-01]
#  [-1.73426342e+00 -5.39456874e-01 -1.86298687e-01 ... -3.62167870e-01
#    1.37995704e+00 -7.66919299e-01]
#  [-1.73340181e+00 -3.20031232e-01 -1.86298687e-01 ... -3.62167870e-01
#    1.41192021e+00 -7.66919299e-01]
#  ...
#  [ 1.72682006e+00 -4.29480975e-05 -1.86298687e-01 ... -3.62167870e-01
#   -1.31560393e+00  1.30391816e+00]
#  [ 1.72768167e+00 -1.85606976e-01 -1.86298687e-01 ... -9.85033311e-02
#   -1.31608822e+00 -7.66919299e-01]
#  [ 1.72854328e+00 -7.00507951e-01 -1.86298687e-01 ... -3.62167870e-01
#   -1.31754109e+00 -7.66919299e-01]]

# %% [markdown]
# # K-CLUSTERING

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(20, 10))
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i,random_state = 0)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1,11), wcss)
plt.title('Elbow curve')
plt.xlabel('number of curve')
plt.ylabel('wcss')
plt.show()

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(df_standardized)

y_kmeans
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
#beginning of  the cluster numbering with 1 instead of 0
y_kmeans1=y_kmeans+1

# New list called cluster
cluster = list(y_kmeans1)
# Adding cluster to our data set
df['cluster'] = cluster

# %%
#Mean of clusters 1 to 4
kmeans_mean_cluster = pd.DataFrame(round(df.groupby('cluster').mean(),1))
kmeans_mean_cluster
# Out:
#             ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# cluster
# 1        1096.0   57102.4       104.4        1.4        1.0        1.0
# 2        3135.2   39803.1       103.8        1.4        1.0        1.0
# 3        1735.5  197550.8       826.3        2.2        1.0        1.0
# 4        1540.2  127132.4       153.0        4.0        1.0        1.0
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# cluster
# 1             5904.6          8.0              234.1              0.7
# 2             6208.7          7.8              205.2              0.6
# 3            32996.1         28.1             5519.0             16.4
# 4            45686.2         19.5              371.5              1.1
#
#          Days_since_enroll  Award?
# cluster
# 1                   5710.7     0.3
# 2                   2150.3     0.2
# 3                   4706.2     0.8
# 4                   4965.9     0.7

# %%
df[df['cluster']==1]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 2176  2193   194875           0          1          1          1         7550
# 2184  2201   109268           0          2          1          1         7401
# 2194  2211    81251           0          1          1          1        19500
# 2200  2217    12271         500          2          1          1         7684
# 2202  2219    35445           0          1          1          1         3379
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 5               0                  0                0               6942
# ...           ...                ...              ...                ...
# 2176            6               1050                3               3831
# 2184           17                750                1               4034
# 2194            6                  0                0               3958
# 2200           15               1000                2               4219
# 2202            9                  0                0               4198
#
#       Award?  cluster
# 0          0        1
# 1          0        1
# 2          0        1
# 3          0        1
# 5          0        1
# ...      ...      ...
# 2176       1        1
# 2184       0        1
# 2194       1        1
# 2200       0        1
# 2202       1        1
#
# [1299 rows x 13 columns]

# %%
df[df['cluster']==2]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 1129  1141     1625           0          1          1          1         1375
# 1424  1438    22093           0          3          1          1        14857
# 1950  1967    15676           0          1          1          1            0
# 1951  1968    55064           0          2          1          1         8041
# 1952  1969    40675           0          1          1          1         1413
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 1129            4                  0                0               1547
# 1424           11                200                1               2587
# 1950            0                  0                0               3178
# 1951           13                  0                0               3329
# 1952            9                  0                0               2895
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?  cluster
# 1129       0        2
# 1424       0        2
# 1950       0        2
# 1951       1        2
# 1952       0        2
# ...      ...      ...
# 3994       1        2
# 3995       1        2
# 3996       1        2
# 3997       0        2
# 3998       0        2
#
# [1533 rows x 13 columns]

# %%
df[df['cluster']==3]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 8        9   443003           0          3          2          1         1753
# 42      43    60313           0          1          1          1        10000
# 65      66    53914           0          3          1          1        33767
# 94      97   185549           0          5          1          1       110859
# 112    115   124198           0          5          1          1        66330
# ...    ...      ...         ...        ...        ...        ...          ...
# 3907  3930   126490           0          1          1          1         8808
# 3911  3934    55922        2273          1          1          1         8104
# 3917  3940   130748           0          4          1          1        65510
# 3934  3957    76595           0          1          1          1        10577
# 3950  3973    59650           0          1          1          1         5050
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 8              43               3850               12               6948
# 42             26               3250                9               7829
# 65             45               5550               29               6826
# 94             39               2950               16               6778
# 112            23               4833               10               7710
# ...           ...                ...              ...                ...
# 3907           15               5183               12               1566
# 3911           19               4104               16               1552
# 3917           37               6349                7               1545
# 3934            2               9577                1               1515
# 3950           16               3950               13               1476
#
#       Award?  cluster
# 8          1        3
# 42         1        3
# 65         1        3
# 94         1        3
# 112        0        3
# ...      ...      ...
# 3907       0        3
# 3911       0        3
# 3917       0        3
# 3934       0        3
# 3950       0        3
#
# [153 rows x 13 columns]

# %%
df[df['cluster']==4]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4        5    97752           0          4          1          1        43300
# 6        7    84914           0          3          1          1        27482
# 9       10   104860           0          3          1          1        28426
# 11      12    96522           0          5          1          1        61105
# 15      16    28495           0          4          1          1        49442
# ...    ...      ...         ...        ...        ...        ...          ...
# 3881  3904    32424           0          4          1          1        39635
# 3883  3906   126167           0          5          1          1       190160
# 3897  3920   179832        2954          3          1          1        18218
# 3908  3931    57642           0          4          1          1        52176
# 3930  3953    40424           0          4          1          1        44110
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 4              26               2077                4               6935
# 6              25                  0                0               6994
# 9              28               1150                3               6931
# 11             19                  0                0               6924
# 15             15                  0                0               6912
# ...           ...                ...              ...                ...
# 3881           16                  0                0               1584
# 3883           15                  0                0               1612
# 3897           20               2500                5               1569
# 3908           15                  0                0               1564
# 3930           26                343                3               1523
#
#       Award?  cluster
# 4          1        4
# 6          0        4
# 9          1        4
# 11         1        4
# 15         1        4
# ...      ...      ...
# 3881       1        4
# 3883       1        4
# 3897       1        4
# 3908       1        4
# 3930       1        4
#
# [1014 rows x 13 columns]

# %% [markdown]
# # CSV FILE DOWNLOAD AFTER CLUSTERING

# %%
from IPython.display import HTML
import base64

data = df
def create_download_link( data, title = "Download CSV file After the Clustering", filename = "airlines.csv"):  
    csv = data.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(df)
# Out:
# <a download="airlines.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file After the Clustering</a>

# %% [markdown]
# # DBSCAN Clustering

# %%
array=df.values
array
# Out:
# array([[    1, 28143,     0, ...,     0,  7000,     0],
#        [    2, 19244,     0, ...,     0,  6968,     0],
#        [    3, 41354,     0, ...,     0,  7034,     0],
#        ...,
#        [ 4019, 73597,     0, ...,     0,  1402,     1],
#        [ 4020, 54899,     0, ...,     1,  1401,     0],
#        [ 4021,  3016,     0, ...,     0,  1398,     0]], dtype=int64)

# %%
stscaler = StandardScaler().fit(array)
X = stscaler.transform(array)
X
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
db_default = DBSCAN(eps = 0.8, min_samples = 12).fit(X)
labels = db_default.labels_

# %%
#-1 is an noise
labels
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
data=pd.DataFrame(labels,columns=['db_cluster'])

# %%
data
# Out:
#       db_cluster
# 0              0
# 1              0
# 2              0
# 3              0
# 4             -1
# ...          ...
# 3994           1
# 3995           1
# 3996           1
# 3997           0
# 3998           0
#
# [3999 rows x 1 columns]

# %%
pd.concat([data,df],axis=1)
# Out:
#       db_cluster   ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0              0     1    28143           0          1          1          1
# 1              0     2    19244           0          1          1          1
# 2              0     3    41354           0          1          1          1
# 3              0     4    14776           0          1          1          1
# 4             -1     5    97752           0          4          1          1
# ...          ...   ...      ...         ...        ...        ...        ...
# 3994           1  4017    18476           0          1          1          1
# 3995           1  4018    64385           0          1          1          1
# 3996           1  4019    73597           0          3          1          1
# 3997           0  4020    54899           0          1          1          1
# 3998           0  4021     3016           0          1          1          1
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0             174            1                  0                0
# 1             215            2                  0                0
# 2            4123            4                  0                0
# 3             500            1                  0                0
# 4           43300           26               2077                4
# ...           ...          ...                ...              ...
# 3994         8525            4                200                1
# 3995          981            5                  0                0
# 3996        25447            8                  0                0
# 3997          500            1                500                1
# 3998            0            0                  0                0
#
#       Days_since_enroll  Award?
# 0                  7000       0
# 1                  6968       0
# 2                  7034       0
# 3                  6952       0
# 4                  6935       1
# ...                 ...     ...
# 3994               1403       1
# 3995               1395       1
# 3996               1402       1
# 3997               1401       0
# 3998               1398       0
#
# [3999 rows x 13 columns]

# %% [markdown]
# # Hierarchical Clustering

# %%
# Normalization function 
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# Normalized data frame (considering the numerical part of data)
df_norm = norm_func(df.iloc[:,:10])

# %%
df_norm
# Out:
#            ID#   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12
# 0        0.000660     0.011628           0.000000         0.000000
# 1        0.000815     0.023256           0.000000         0.000000
# 2        0.015636     0.046512           0.000000         0.000000
# 3        0.001896     0.011628           0.000000         0.000000
# 4        0.164211     0.302326           0.067398         0.075472
# ...           ...          ...                ...              ...
# 3994     0.032330     0.046512           0.006490         0.018868
# 3995     0.003720     0.058140           0.000000         0.000000
# 3996     0.096505     0.093023           0.000000         0.000000
# 3997     0.001896     0.011628           0.016225         0.018868
# 3998     0.000000     0.000000           0.000000         0.000000
#
# [3999 rows x 10 columns]

# %%
df_norm.drop('ID#',
  axis='columns', inplace=True)

# %%
X = df_norm.iloc[:,:10]
y = df.iloc[:,11:]

# %%
X.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12
# 0     0.011628           0.000000         0.000000
# 1     0.023256           0.000000         0.000000
# 2     0.046512           0.000000         0.000000
# 3     0.011628           0.000000         0.000000
# 4     0.302326           0.067398         0.075472

# %%
y.head()
# Out:
#    Award?
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1

# %%
# import hierarchical clustering libraries
import scipy.cluster.hierarchy as sch

# %%
plt.figure(figsize =(10, 10))
plt.title('Visualising the data')
# create dendrogram
Dendrogram = sch.dendrogram((sch.linkage(df_norm, method ='ward')))

# %%
# create clusters
from sklearn.cluster import AgglomerativeClustering
ac = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'ward')

# %%
ac
# Out:
# AgglomerativeClustering(n_clusters=5)

# %%
# save clusters for chart
y_ac = ac.fit_predict(X)
Clusters=pd.DataFrame(y_ac,columns=['Clusters'])

# %%
X['hw_clusterid'] = ac.labels_
# Out:
# <ipython-input-19-5b270b56a28e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['hw_clusterid'] = ac.labels_

# %%
X
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  hw_clusterid
# 0        0.011628           0.000000         0.000000             0
# 1        0.023256           0.000000         0.000000             0
# 2        0.046512           0.000000         0.000000             0
# 3        0.011628           0.000000         0.000000             0
# 4        0.302326           0.067398         0.075472             1
# ...           ...                ...              ...           ...
# 3994     0.046512           0.006490         0.018868             0
# 3995     0.058140           0.000000         0.000000             0
# 3996     0.093023           0.000000         0.000000             2
# 3997     0.011628           0.016225         0.018868             0
# 3998     0.000000           0.000000         0.000000             0
#
# [3999 rows x 10 columns]

# %%
X['hw_clusterid'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
X.groupby('hw_clusterid').agg(['mean']).reset_index()
# Out:
#   hw_clusterid   Balance Qual_miles cc1_miles cc2_miles cc3_miles Bonus_miles  \
#                     mean       mean      mean      mean      mean        mean
# 0            0  0.029417   0.014595  0.001440  0.000000  0.000111    0.014139
# 1            1  0.066643   0.024582  0.749561  0.000877  0.021053    0.164276
# 2            2  0.045004   0.003354  0.422612  0.000000  0.000000    0.064557
# 3            3  0.040529   0.002136  0.017857  0.678571  0.000000    0.051853
# 4            4  0.105184   0.006666  0.999042  0.000000  0.000000    0.291916
#
#   Bonus_trans Flight_miles_12mo Flight_trans_12
#          mean              mean            mean
# 0    0.075311          0.014425        0.025171
# 1    0.241269          0.026825        0.047567
# 2    0.183477          0.007709        0.012723
# 3    0.204873          0.019356        0.042677
# 4    0.244988          0.016623        0.026314

# %%
# create dendrogram
dendrogram = sch.dendrogram(sch.linkage(df_norm, method='complete'))

# %%
# create clusters
ac1 = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'complete')

# %%
# save clusters for chart
y_ac1 = ac1.fit_predict(X)
Clusters=pd.DataFrame(y_ac1,columns=['Clusters'])

# %%
X['hc_clusterid'] = ac1.labels_
# Out:
# <ipython-input-26-941c502be041>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['hc_clusterid'] = ac1.labels_

# %%
X
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  hw_clusterid  \
# 0        0.011628           0.000000         0.000000             0
# 1        0.023256           0.000000         0.000000             0
# 2        0.046512           0.000000         0.000000             0
# 3        0.011628           0.000000         0.000000             0
# 4        0.302326           0.067398         0.075472             1
# ...           ...                ...              ...           ...
# 3994     0.046512           0.006490         0.018868             0
# 3995     0.058140           0.000000         0.000000             0
# 3996     0.093023           0.000000         0.000000             2
# 3997     0.011628           0.016225         0.018868             0
# 3998     0.000000           0.000000         0.000000             0
#
#       hc_clusterid
# 0                1
# 1                1
# 2                1
# 3                1
# 4                0
# ...            ...
# 3994             1
# 3995             1
# 3996             0
# 3997             1
# 3998             1
#
# [3999 rows x 11 columns]

# %%
X['hc_clusterid'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
dendrogram = sch.dendrogram(sch.linkage(df_norm, method ='average'))

# %%
# create clusters
ac2 = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'average')

# %%
# save clusters for chart
y_ac2 = ac2.fit_predict(df_norm)
Clusters=pd.DataFrame(y_ac2,columns=['Clusters'])

# %%
X['hs_clusterid'] = ac2.labels_

# %%
X['hs_clusterid'].value_counts().plot.bar()

# %%
X
